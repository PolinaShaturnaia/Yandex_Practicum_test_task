# %% [markdown]
# Привет, Полина!
#
# Меня зовут Светлана Медведева и я буду проверять Твою работу. Предлагаю общаться на "ты". Если Тебе такой вариант не удобен. то пожалуйста дай знать. Я сразу перейду на "Вы".
#
# При обнаружении у Тебя в работе ошибки, в первый раз я лишь укажу на ее наличие и у Тебя будет возможность самому найти её и исправить. В реальной работе твой начальник будет поступать также, а я пытаюсь подготовить тебя именно к работе аналитиком. Однако если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.
#
# Просьба при доработке работы оставлять мои комментарии без изменений.
#
# Комментарии я разделяю на следующие категории:
#
# <div class="alert alert-block alert-success">
# В случае если всё верно!
# </div>
#
#
# <div class="alert alert-block alert-warning">
# В случае если можно что-то доработать, но эта доработка не критична или если есть варианты улучшения работы.
# </div>
#
# <div class="alert alert-block alert-danger">
# Замечания, которые нужно исправить. Без исправления этих замечаний проект принят не может быть.
# </div>
#
# ### <font color='blue'>Резензия на работу v. 1</font> <a class="tocSkip">
# * Исправь, пожалуйста, ошибку в коде и я смогу продолжить проверку проекта.
# * Успехов!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Светлана, привет!
#
# Приветствую тебя.
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#01.-Цель-проекта:" data-toc-modified-id="01.-Цель-проекта:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>01. Цель проекта:</a></span></li><li><span><a href="#02.-Инструкция-по-выполнению-проекта" data-toc-modified-id="02.-Инструкция-по-выполнению-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>02. Инструкция по выполнению проекта</a></span></li><li><span><a href="#1.-Подготовка" data-toc-modified-id="1.-Подготовка-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>1. Подготовка</a></span><ul class="toc-item"><li><span><a href="#1.1.-Изучим-данные-из-файла" data-toc-modified-id="1.1.-Изучим-данные-из-файла-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>1.1. Изучим данные из файла</a></span></li><li><span><a href="#1.2.-Проверим-данные-на-ошибки" data-toc-modified-id="1.2.-Проверим-данные-на-ошибки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>1.2. Проверим данные на ошибки</a></span></li><li><span><a href="#1.3.-Подготовим-данные" data-toc-modified-id="1.3.-Подготовим-данные-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>1.3. Подготовим данные</a></span></li></ul></li><li><span><a href="#2.-Обучение" data-toc-modified-id="2.-Обучение-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>2. Обучение</a></span><ul class="toc-item"><li><span><a href="#2.1.-Сформируем-тренировочную-и-валидационную-выборки" data-toc-modified-id="2.1.-Сформируем-тренировочную-и-валидационную-выборки-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>2.1. Сформируем тренировочную и валидационную выборки</a></span></li><li><span><a href="#2.2.-Обучим-модели" data-toc-modified-id="2.2.-Обучим-модели-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>2.2. Обучим модели</a></span></li><li><span><a href="#2.3.-F1-мера" data-toc-modified-id="2.3.-F1-мера-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>2.3. F1-мера</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Дорогой ревьюер, привет)
#
# К сожалению, как я не пыталась в команде с преподавателем в рамках своего уровня знаний добиться при помощи BERT значения F1-меры больше 0,75, у меня не вышло.
#
# И на BERT, совместно с COLAB ушло около 4 дней. Не хотелось все бросать и переходить к TF-IDF.
#
# Буду очень рада, если будут советы по улучшению качества моделей.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Комментарий ревьюера v. 1:
#
# К сожалению, из-за ошибке при запуске проект не готов к ревью...
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Светлана, ниже все прокомментировала.
# </div>

# %% [markdown]
# ### <font color='blue'>Резензия на работу v. 3</font> <a class="tocSkip">
# * К сожалению, при запуске проекта возникает ошибка "ValueError: Input contains NaN, infinity or a value too large for dtype('float32')." Я видела твой комментарий, что Ты заменила на NaN значения на среднее, но код дальше тоже не запускается... Возможно, это было не последняя версия (повторный запуск и загрузка датасетов в колаб займёт много времени), поэтому если сейчас исправлено, то ок). Исправь, пожалуйста, разделение датасета на обчающую и тестовую выборки. Нужно изменить соотношение обучающей и тестовой выборок (скорее всего из-за этого требуемое значение метрики не было достигнуто).
# * Жду исправленную работу :)

# %% [markdown]
# <h1>Проект для «Викишоп» с BERT

# %% [markdown]
# <i>Для проверки работы проекта необходимо:
#
#     1. Скачать файлы для BERT
#     2. Установить torch, transformers и catboost (для этого, уважаемый ревьюер, раскомментируй первые три строки в Ввод [1]
#     3. Скачать файл с признаками, полученными в COLAB.
#
# Ссылка на скачивание доп. файлов по BERT:
#
#     vocab.txt: https://disk.yandex.ru/d/3zcj-_oTuJ0rmg
#     bert_config.json: https://disk.yandex.ru/i/zEkUPXW7-1fl7w
#     pytorch_model.bin: https://disk.yandex.ru/d/tyova2SyD0NkNQ
#
# Ссылка на скачивание самого датафрейма:
#
#     https://disk.yandex.ru/d/D30hjQBL0pTDdA
#
#
# Ссылка на скачивание features:
#
#     https://disk.yandex.ru/d/HW8cBJgL662-Xg
#
# <i>Файлы надо скачать и разместить в папке с проектом.

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.

# %% [markdown]
# <h2>01. Цель проекта:

# %% [markdown]
# <b>Обучить модель классифицировать комментарии на позитивные и негативные. В нашем распоряжении набор данных с разметкой о токсичности правок.

# %% [markdown]
# Построим модель со значением метрики качества *F1* не меньше 0.75.

# %% [markdown]
# <h2>02. Инструкция по выполнению проекта

# %% [markdown]
#     1. Загрузим и подготовим данные.
#     2. Обучим разные модели.
#     3. Сделаем выводы.
#
# Для выполнения проекта применим *BERT*.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Молодец, что кратко описала проект.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Спасибо.
# </div>

# %% [markdown]
# <h2>1. Подготовка

# %% [markdown]
# <h3>1.1. Изучим данные из файла

# %% [markdown]
# <b>1.1.2. Импортируем необходимые нам алгоритмы и функции:

# %%
#!pip install torch -U
#!pip install transformers -U
#!pip3 install catboost -U

import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.options.mode.chained_assignment = None
import torch #PyTorch применяется в задачах обработки естественного текста и компьютерного зрения
import transformers #Библиотека PyTorch для работы с моделями типа BERT
import numpy as np
from tqdm import notebook # Библиотека tqdm нужна, чтобы наглядно показать индикатор прогресса. В Jupyter применим функцию notebook() из этой библиотеки
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import time
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# <b>1.1.3. Импортируем данные:

# %%
data = pd.read_csv('toxic_comments.csv')
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e1cef18ef000> in <module>
# ----> 1 data = pd.read_csv('toxic_comments.csv')
#       2 pd.set_option('display.max_columns', None)
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'toxic_comments.csv' does not exist: b'toxic_comments.csv'

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Отлично, данные загружены.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> +
# </div>

# %%
print('Посмотрим на первые 5 строк датафрейма data:')
display(data.head())
print('')
print('')
print('Посмотрим общую информацию о датафрейме применив метод .info()')
display(data.info())

# %% [markdown]
# <b>1.1.4. Описание данных

# %% [markdown]
# Данные находятся в файле `toxic_comments.csv`.
#
#     - Столбец *text* содержит текст комментария
#     - Столбец *toxic* содержит целевой признак

# %% [markdown]
# <h3>1.2. Проверим данные на ошибки

# %% [markdown]
# В данных отсутствуют NAN-значения.
#
# Проверим, присутствуют ли в данных задублированные записи.

# %%
data.duplicated().sum()

# %% [markdown]
# Задублированных записей нет.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Да, дубликатов и пропусков у нас нет.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> +
# </div>

# %% [markdown]
# <h3>1.3. Подготовим данные

# %% [markdown]
# В целях обучения модели классификации применим векторные представления на базе **BERT**.
#
# Построить векторы текстов нам поможет предобученная на русских текстах модель **RuBERT**.

# %% [markdown]
# <b>1.3.1. Начинаем предобработку текстов:

# %% [markdown]
# <i>Следующий код представлен для ознакомления и закомментирован, поскольку был выполнен с помощью аппаратного ускорителя GPU в COLAB.

# %% [markdown]
# Инициализируем токенизатор как объект класса **BertTokenizer()**.
#
# Передадим ему аргумент **vocab_file** — это файл со словарём, на котором обучалась модель.

# %% [markdown]
# <i>Получение эмбеддингов на локальном компьютере без ускорения GPU у нас заняло бы около 80 часов.
#
# Поэтому обратимся к COLAB и подключим аппаратный ускоритель GPU.
#
# Оставим закомментированный код, чтобы описать этапы получения эмбенддингов.

# %%
#tokenizer = transformers.BertTokenizer(vocab_file = 'vocab.txt')

# %% [markdown]
# Токенизируем каждую запись:

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Расскоментировала весь код, но при запуске проекта получила следующую ошибку: "ValueError: Can't find a vocabulary file at path 'conversational_cased_L-12_H-768_A-12_pt/vocab.txt'. To load the vocabulary from a Google pretrained model use `tokenizer = BertTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)`".
#
# Проверь, пожалуйста, проект перед отправкой на отсутствие ошибок при запуске.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Светлана, я предполагала, что этот код не будет запускаться в Jupyter, поскольку он был выполнен с помощью COLAB при поддержке аппаратного ускорителя GPU.
#
# Здесь он указан как пример и не требует запуска, поскольку его результат предлагается к загрузке как файл.
#
# Но в любом случае, я исправила код, чтобы при желании его можно было попробовать запустить через Jupyter.
# </div>

# %%
#tokenized = data['text'].apply(lambda x: tokenizer.encode(x, add_special_tokens = True, truncation=True, max_length=512))

# %% [markdown]
# Пусть стандартной длиной вектора n будет длина наибольшего во всём датасете вектора. Остальные векторы дополним нулями:

# %%
#max_len = 0
#for i in tokenized.values:
#    if len(i) > max_len:
#        max_len = len(i)
#
#padded = np.array([i + [0] * (max_len - len(i)) for i in tokenized.values])

# %% [markdown]
# Теперь поясним модели, что нули не несут значимой информации.
#
# Отбросим эти токены и «создадим маску» для действительно важных токенов, то есть укажем нулевые и не нулевые значения:

# %%
#attention_mask = np.where(padded != 0, 1, 0)

# %% [markdown]
# Инициализируем конфигурацию **BertConfig**.
#
# В качестве аргумента передадим ей **JSON-файл** с описанием настроек модели.

# %%
#config = transformers.BertConfig.from_json_file('bert_config.json')

# %% [markdown]
# Инициализируем саму модель класса **BertModel**.
#
# Передадим ей файл с предобученной моделью:

# %%
#model = transformers.BertModel.from_pretrained('pytorch_model.bin', config = config)

# %% [markdown]
# <i>Подключение GPU:</i>

# %%
#Версия кода для запуска в COLAB

#model = model.cuda()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Светлана, также в случае запуска кода в Jupyter, строку выше не нужно раскомментировать.
#
# Она нужна исключительно для COLAB.
# </div>

# %% [markdown]
# Эмбеддинги модель BERT создаёт **батчами**. Чтобы хватило оперативной памяти, сделаем размер батча небольшим:

# %%
#batch_size = 100

# %% [markdown]
# Сделаем цикл по батчам. Отображать прогресс будет функция **notebook()**.
#
# Преобразуем данные в формат **тензоров** — многомерных векторов в библиотеке torch.
#
# Тип данных **LongTensor** хранит числа в «длинном формате», то есть выделяет на каждое число 64 бита.
#
# Чтобы получить эмбеддинги для батча, передадим модели данные и маску.
#
# Для ускорения вычисления функцией **no_grad()** в библиотеке torch укажем, что градиенты не нужны: модель BERT обучать не будем.
#
# Из полученного тензора извлечём нужные элементы и добавим в список всех эмбеддингов.

# %%
# Версия кода для запуска в COLAB

#embeddings = []
#
#for i in notebook.tqdm(range(padded.shape[0] // batch_size)):
#    batch = torch.LongTensor(padded[batch_size * i:batch_size * (i + 1)]).cuda() 
#    attention_mask_batch = torch.LongTensor(attention_mask[batch_size * i:batch_size * (i + 1)]).cuda() 
#    
#    with torch.no_grad():
#        batch_embeddings = model(batch, attention_mask = attention_mask_batch)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Аналогично. Код написан для COLAB. В случае запуска его на Jupyter, прошу не раскомментировать код выше, а использовать вариант кода ниже:
# </div>

# %%
# Версия кода для запуска в Jupyter

#embeddings = []
#
#for i in notebook.tqdm(range(padded.shape[0] // batch_size)):
#    batch = torch.LongTensor(padded[batch_size * i:batch_size * (i + 1)]) 
#    attention_mask_batch = torch.LongTensor(attention_mask[batch_size * i:batch_size * (i + 1)]) 
#    
#    with torch.no_grad():
#        batch_embeddings = model(batch, attention_mask = attention_mask_batch)

# %% [markdown]
# <i>Возвращение к CPU:

# %%
# Версия кода для запуска в COLAB

#    embeddings.append(batch_embeddings[0][:,0,:].cpu().numpy())

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Тоже самое. В случае запуска кода на Jupyter, прошу не раскомментировать код выше, а использовать вариант кода ниже:
# </div>

# %%
# Версия кода для запуска в Jupyter

#    embeddings.append(batch_embeddings[0][:,0,:].numpy())

# %% [markdown]
# Вот так проходил процесс создание эмбеддингов:
#
# ![1.png](attachment:1.png)

# %% [markdown]
# Соберём все эмбеддинги в матрицу признаков вызовов функции **concatenate()**:

# %%
#features = np.concatenate(embeddings)

# %% [markdown]
# Мы уже подготовили файл с признаками и сейчас просто выгрузим его.
#
# Подготовка файла происходила следующим образом в COLAB:

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Следующая ячейка необходима исключительно для работы в COLAB. Для запуска в Jupyter указан вариант выше.
# </div>

# %%
# Версия кода для запуска в COLAB

#data_features = []
#data_features['features'] = features
#data_features.to_csv('features', index = False)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №1:</b> Подвегу итог.
#
# Подразумевалось, что закомментированный код не будет запущен, посколько он отработал в COLAB и его результат мы загружаем в следующей ячейке.
#
# Закомментированный код представлен исключительно в целях ознакомления.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №3:</b> Светлана, к сожалению, твой вариант, код:
#
# https://pastebin.com/QypXDevq
#
#
# https://stackoverflow.com/questions/56611698/pandas-how-to-read-csv-file-from-google-drive-public
#
# дал вот такой результат:
#
# ![1.1.png](attachment:1.1.png)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №3:</b> Также вариант от сюда:
#
# https://www.notion.so/0df6a36d3a904b368a8699568db5ed64
#
# не сработал. Файл слишком большой:
#
# ![1.2.png](attachment:1.2.png)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №3:</b> При этом при всем с самим файлом все в порядке.
#
# ![1.3.png](attachment:1.3.png)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента №3:</b> Направляю на проверку еще раз вариант проекта, при котором тебе нужно самостоятельно скачать файлы по ссылкам в самом верху.
# </div>

# %%
data_features = pd.read_csv('features')

# %% [markdown]
# Сформируем новый датафрейм.
#
# Как мы помним, всего у нас было 159571 запись. После получения эмбеддингов, мы сформировали датафрейм из 159500 признаков.
#
# При попытке сформировать для оставшихся 71 записи отдельно эмбеддинги - мы получили ошибку недостатка памяти:
#
# ![image.png](attachment:image.png)
#
# <b>Комментарий студента:</b> Я хочу попытаться сдать проект и получить комментарий еще от кого-то.
# Я удалю эти 71 запись, это 0,04% данных.

# %%
new_data = data_features
target = data['toxic']
target.drop(target.tail(71).index,inplace = True)
new_data['target'] = data['toxic']

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Да, эти данные составляют менее 1 % и их можно удалить)
# </div>

# %% [markdown]
# <h2>2. Обучение

# %% [markdown]
# <h3>2.1. Сформируем тренировочную и валидационную выборки

# %%
features = new_data.drop(['target'], axis=1)
target = new_data['target']

# %%
features = features.astype('float16')

# %% [markdown]
# Разделим признаки и target на обучающую и тестовую (валидационую выборки) в соотношении 50%/50%.

# %%
features_train, features_valid, target_train, target_valid = train_test_split(
    features, target, test_size = 0.25, random_state = 12345)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Обычно тестовая выборка составляет около 30 % от обучающей. 50 % это слишком мало для обучения.
# </div>

# %% [markdown]
# Посмотрим на размеры полученных выборок

# %%
print('Размер тренировоной выборки:')
display('Признаки.Тренировочная выборка:', features_train.shape)
display('Целевой признак.Тренировочная выборка:', target_train.shape)
print('')
print('Размер валидационной выборки:')
display('Признаки.Валидационная выборка:', features_valid.shape)
display('Целевой признак.Валидационная выборка:', target_valid.shape)

# %% [markdown]
# Оценим баланс между значениями в столбце, отвечающем за целевой признак.

# %%
target.value_counts()

# %% [markdown]
# В наших данных <b>присутствует дисбаланс</b>. Это необходимо скорректировать.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Комментарий ревьюера v. 1:
#
# Да, у нас наблюдается дисбаланс классов. Молодец, что обратила на это внимание.
#
# Дополнительные материалы: https://www.analyticsvidhya.com/blog/2020/11/handling-imbalanced-data-machine-learning-computer-vision-and-nlp/
# </div>

# %% [markdown]
# <h3>2.2. Обучим модели

# %% [markdown]
# Помимо рассчета F1-меры, сохраним необходимое для обучения модели время.

# %% [markdown]
# <b>2.2.1. Дерево решений

# %%
start_time = time.time()

model_DTC = DecisionTreeClassifier(random_state = 12345, class_weight='balanced')
model_DTC = model_DTC.fit(features_train, target_train)
model_DTC_predictions = model_DTC.predict(features_valid)

end_time = time.time()
time_model = round((end_time - start_time), 2)

f1 = f1_score(target_valid, model_DTC_predictions)
print("F1-мера для Дерева решений на валидационной выборке:", f1)
print("Общее время обучения модели", time_model, 'секунд')

# %% [markdown]
# Запишем значение F1-Меры для Дерева решений.

# %%
DecisionTreeClassifier_data = pd.DataFrame({'model': ['DecisionTreeClassifier'], 'F1': [f1], 'time': [time_model]})
display (DecisionTreeClassifier_data)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Комментарий ревьюера v. 1:
#
# Добавь, пожалуйста, описание модели, т. е. какие гиперпараметры рассмотрены.
# </div>

# %% [markdown]
# <b>2.2.2. Случайный лес

# %%
best_model = None
best_result = 0
best_est = None

for est in range(1, 11):
    model_RFC = RandomForestClassifier(random_state = 12345, n_estimators = est, class_weight='balanced')
    model_RFC = model_RFC.fit(features_train, target_train)
    model_RFC_predictions = model_RFC.predict(features_valid)
    result = f1_score(target_valid, model_RFC_predictions)
    if result > best_result:
        best_model = model_RFC
        best_result = result
        best_est = est

# %%
start_time = time.time()

model_RFC = RandomForestClassifier(random_state = 12345, n_estimators = best_est, class_weight='balanced')
model_RFC = model_RFC.fit(features_train, target_train)
model_RFC_predictions = model_RFC.predict(features_valid)

end_time = time.time()
time_model =  round((end_time - start_time), 2)

f1 = f1_score(target_valid, model_RFC_predictions)
print("F1-мера для Случайного леса на валидационной выборке:", f1)
print("Наилучшее количество деревьев", best_est)
print("Общее время обучения модели", time_model, 'секунд')

# %%
RandomForestClassifier_data = pd.DataFrame({'model': ['RandomForestClassifier'], 'F1': [f1], 'time': [time_model]})
display (RandomForestClassifier_data)

# %% [markdown]
# <b>2.2.3. Логистическая регрессия

# %% [markdown]
# Для логистической регрессии много данных.
#
# Возьмем случайную выборку.

# %%
new_data_2 = new_data.sample(5000).reset_index(drop = True)

features_2 = new_data_2.drop(['target'], axis=1)
target_2 = new_data_2['target']

features_2 = features_2.astype('float16')

features_train_2, features_valid_2, target_train_2, target_valid_2 = train_test_split(
    features_2, target_2, test_size = 0.5, random_state = 12345)

# %%
start_time = time.time()

model_LR = LogisticRegression(random_state = 12345, solver = 'liblinear', class_weight='balanced')
model_LR = model_LR.fit(features_train_2, target_train_2)
model_LR_predictions = model_LR.predict(features_valid_2)

end_time = time.time()
time_model =  round((end_time - start_time), 2)

f1 = f1_score(target_valid_2, model_LR_predictions)
print("F1-мера для Логистичекой регрессии на валидационной выборке:", f1)
print("Общее время обучения модели", time_model, 'секунд')

# %%
LogisticRegression_data = pd.DataFrame({'model': ['LogisticRegression'], 'F1': [f1], 'time': [time_model]})
display (LogisticRegression_data)

# %% [markdown]
# <b>2.2.4. Градиентный бустинг

# %%
start_time = time.time()

model_CBC = CatBoostClassifier(loss_function = "Logloss", iterations = 3, depth = 10)
model_CBC = model_CBC.fit(features_train, target_train, verbose=10)
model_CBC_predictions = model_CBC.predict(features_valid)

end_time = time.time()
time_model = round((end_time - start_time), 2)

f1 = f1_score(target_valid, model_CBC_predictions)
print("F1-мера для Градиентного бустинга на валидационной выборке:", f1)
print("Общее время обучения модели", time_model, 'секунд')

# %%
CatBoostClassifier_data = pd.DataFrame({'model': ['CatBoostClassifier'], 'F1': [f1], 'time': [time_model]})
display (CatBoostClassifier_data)

# %% [markdown]
# <h3>2.3. F1-мера

# %% [markdown]
# Чем выше значение F1-меры, тем лучше.
#
# Напомним, нам необходимо преодолеть порог значения F1-меры в <b>0.75</b>.
#
# Объединим датафреймы с данными о значениях F1-меры на тренировочных выборках.

# %%
pd.concat([DecisionTreeClassifier_data, RandomForestClassifier_data, LogisticRegression_data, CatBoostClassifier_data], ignore_index = True)

# %% [markdown]
# Применим метод поиска наилучших гиперпараметров для модели Логистическая регрессия.

# %%
lr = LogisticRegression()

solver_options = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
#С_options = [0.01, 0.05, 0.1, 0.5, 1, 5, 10]
max_iter_options = [2, 10, 20, 25, 30]
multi_class_options = ['auto', 'ovr', 'multinomial']
penalty_options = ['l1', 'l2', 'elasticnet', 'none']

param_grid = dict(
    solver = solver_options,
    #С = С_options,
    max_iter = max_iter_options,
    multi_class = multi_class_options,
    penalty = penalty_options)

grid = GridSearchCV(lr, param_grid, cv = 5, scoring = 'f1')

grid.fit(features_train_2, target_train_2)

start_time = time.time()

model_LR_2 = LogisticRegression(random_state = 12345, **grid.best_params_)
model_LR_2 = model_LR_2.fit(features_train_2, target_train_2)
model_LR_2_predictions = model_LR_2.predict(features_valid_2)

end_time = time.time()
time_model =  round((end_time - start_time), 2)

f1 = f1_score(target_valid_2, model_LR_predictions)
print("F1-мера для Логистичекой регрессии на валидационной выборке:", f1)
print("Общее время обучения модели", time_model, 'секунд')

# %% [markdown]
# <h2>Выводы

# %% [markdown]
# В данном проекте мы познакомились с возможностью подключения аппаратного ускорителя от COLAB, а также создали эмбеддинги с помощью BERT.
#
# Создание эмбеддингов проходило на стороннем ресурсе. В проекте мы отразили код, а также загрузили результаты получения эмбеддингов.
#
# После мы сформировали новый датафрейм с признаками, в том числе с целевым признаком.
#
# Датафрейм содержал 159 700 записей.
#
# Был обнаружен дисбаланс классов, который мы учли при обучении моделей.
#
# Мы обучили 4 модели машинного обучения:
#
#     Дерево решений
# 	Случайный лес
# 	Логистическая регрессия
# 	Градиентный бустинг
#
# Логистическая регрессия не смогла справиться со всем набором данных, поэтому нам пришлось взять случайный набор элементов в количестве 3000 элементов.
#
# Наибольшое значение F1-меры удалось достичь моделе Логистической регрессии.
#
# Также, эта модель показало наименьшее необходимое количество времени. Но это не объективный признак. Для Логистической регрессии нам пришлось урезать набор данных.
#
# **Задача: достигнуть F1-меры = 0,75 не была достигнута.**

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Модели обучены
# - [ ]  Значение метрики *F1* не меньше 0.75
# - [x]  Выводы написаны
